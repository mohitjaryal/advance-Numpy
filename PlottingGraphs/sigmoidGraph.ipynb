# %% [markdown]
# # Basic graph plotting of sigmoid

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-10,10,100)
y = 1/(1+np.exp(-x))

# %%
# plotting graph 
plt.plot(x,y)
