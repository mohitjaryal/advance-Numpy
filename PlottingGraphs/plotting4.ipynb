# %% [markdown]
# # Basic graph plotting of y = xlog(x)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-10,10,100)
y = x * np.log(x)
# Out:
# /var/folders/9b/pfvkrsns3sx2_k1ncj82klqm0000gn/T/ipykernel_33279/674070989.py:2: RuntimeWarning: invalid value encountered in log
#   y = x * np.log(x)

# %%
# plotting graph 
plt.plot(x,y)
